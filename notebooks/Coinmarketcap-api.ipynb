# %%
import pandas as pd
import numpy as np

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd75ad251-b184-4f3f-81bc-c769db6142a4',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2022-07-02T08:55:38.327Z', 'error_code': 0, 'error_message': None, 'elapsed': 0, 'credit_count': 1, 'notice': None}, 'data': [{'id': 8038, 'name': 'gy0qrvc9rfm', 'symbol': 'i69s7ifn9an', 'slug': 'opbkm469wt', 'cmc_rank': 236, 'num_market_pairs': 7564, 'circulating_supply': 3472, 'total_supply': 1170, 'max_supply': 2110, 'last_updated': '2022-07-02T08:55:38.327Z', 'date_added': '2022-07-02T08:55:38.327Z', 'tags': ['f2lll1dtp9n', '9qxkl5124ph', 'zmqqzizd6mr', 'uqthy2h7rom', 'vow3mn3xyhe', 'gi6yes1uwbw', 'q3myqbf7mfn', '50vns7qonjt', 'xt7tmq7nvh', '02qjgt6zuijd'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7142219870244, 'volume_24h': 1234, 'volume_change_24h': 0.5252089720242674, 'percent_change_1h': 0.8980967384023382, 'percent_change_24h': 0.3669519715132534, 'percent_change_7d': 0.07866724404982328, 'market_cap': 0.2900925891312893, 'market_cap_dominance': 9921, 'fully_diluted_market_cap': 0.8813456696741322, 'last_updated': '2022-07-02T08:55:38.327Z'}}}, {'id': 8210, 'name': '60gjhjdi0te', 'symbol': 'ka4540uu2at', 'slug': 'n9j09gxtdv', 'cmc_rank': 2947, 'num_market_pairs': 2227, 'circulating_supply': 4966, 'total_supply': 7779, 'max_supply': 2966, 'last_updated': '2022-07-02T08:55:38.327Z', 'date_added': '2022-07-02T08:55:38.327Z', 'tags': ['yxox3fsoqk', 'hpg6c7fpujd', 'bfgsth3snru', 'axtq54h9sim', '1v9349r19i6', 'nbe3cak57la', '272ybrt6kwi', 'e18xw5uneud', 'dsweqswhx8', 'uruoy8bs9sn'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.554097915613877, 'volume_24h': 1266, 'volume_change_24h': 0.284565436378341, 'percent_change_1h': 0.9721012787959913, 'percent_change_24h': 0.5523624706058758, 'percent_change_7d': 0.2274736536338453, 'market_cap': 0.10276754809220345, 'market_cap_dominance': 9690, 'fully_diluted_market_cap': 0.44693452873663975, 'last_updated': '2022-07-02T08:55:38.327Z'}}}, {'id': 6140, 'name': 'wzppw19g7zc', 'symbol': 'sp2qmfqe4ep', 'slug': '0u9ngz0l59f', 'cmc_rank': 3147, 'num_market_pairs': 2211, 'circulating_supply': 3635, 'total_supply': 3847, 'max_supply': 3127, 'last_updated': '2022-07-02T08:55:38.327Z', 'date_added': '2022-07-02T08:55:38.327Z', 'tags': ['9diq91e7xzo', '4nygqxtlyk', 'g04nyj8fgdc', '6iquu0ryecl', 'qrwt5iid34', '6boud9n2e2b', 'q18z99ae9rp', 'm09tse6hso9', '4u4jbwgcjpn', 'akmtz46e3x9'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.2240120545357196, 'volume_24h': 1223, 'volume_change_24h': 0.4617087022077144, 'percent_change_1h': 0.4795605036158077, 'percent_change_24h': 0.0841335176941187, 'percent_change_7d': 0.02033941935494976, 'market_cap': 0.7648509533328045, 'market_cap_dominance': 4855, 'fully_diluted_market_cap': 0.879558249689294, 'last_updated': '2022-07-02T08:55:38.327Z'}}}, {'id': 9231, 'name': '71bl2gmbi9l', 'symbol': 'dgycdeg6k1d', 'slug': 'x2pi74dw86', 'cmc_rank': 7879, 'num_market_pairs': 7790, 'circulating_supply': 5525, 'total_supply': 6497, 'max_supply': 1445, 'last_updated': '2022-07-02T08:55:38.327Z', 'date_added': '2022-07-02T08:55:38.327Z', 'tags': ['uzju3udc8f', 'wewj4bweuk', '35a782eh2z5', 'mkef66oxol', '40h7x61vqtd', 'h9oc9ye2no8', 'rzjl2xwljtc', 'ofwd6p0i9hi', 'taxacxh493', 'yc3kcjne1uc'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7659518571431769, 'volume_24h': 8159, 'volume_change_24h': 0.5317765012888416, 'percent_change_1h': 0.674519056600767, 'percent_change_24h': 0.6254401824318001, 'percent_change_7d': 0.5056104128565801, 'market_cap': 0.8910071577018712, 'market_cap_dominance': 9584, 'fully_diluted_market_cap': 0.2068410095369193, 'last_updated': '2022-07-02T08:55:38.327Z'}}}, {'id': 6443, 'name': '3ughl68p9ov', 'symbol': 's1d7iiz1o7', 'slug': 'jxrq1rftnes', 'cmc_rank': 3791, 'num_market_pairs': 1627, 'circulating_supply' ...

# %%
data_df = pd.DataFrame(data.items())
data_df
# Out:
#         0                                                  1
# 0  status  {'timestamp': '2022-07-02T08:55:38.327Z', 'err...
# 1    data  [{'id': 8038, 'name': 'gy0qrvc9rfm', 'symbol':...

# %%
data_df2 = pd.DataFrame(data_df.loc[1, 1])
data_df2
# Out:
#      id          name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  8038   gy0qrvc9rfm  i69s7ifn9an   opbkm469wt       236              7564
# 1  8210   60gjhjdi0te  ka4540uu2at   n9j09gxtdv      2947              2227
# 2  6140   wzppw19g7zc  sp2qmfqe4ep  0u9ngz0l59f      3147              2211
# 3  9231   71bl2gmbi9l  dgycdeg6k1d   x2pi74dw86      7879              7790
# 4  6443   3ughl68p9ov   s1d7iiz1o7  jxrq1rftnes      3791              1627
# 5  6188   m6vuki24u7k   aujkbvfwlo  iyzztsfbg4t      5529              7057
# 6  9286   o7p6g5zufls  nmqeiunmnuh  3i8rctcq6n8      3995              6185
# 7  5902    lx0s62ao8j  rz76lysbgos   lt7lbile4u      7226              2242
# 8  8836  054puouo2lac  gyyozg0zff8  24mspjp29k4       369              4725
# 9  1973   z0w24qgv33e   t0bkbgvkye   pjx268a7vc      7612              7882
#
#    circulating_supply  total_supply  max_supply              last_updated  \
# 0                3472          1170        2110  2022-07-02T08:55:38.327Z
# 1                4966          7779        2966  2022-07-02T08:55:38.327Z
# 2                3635          3847        3127  2022-07-02T08:55:38.327Z
# 3                5525          6497        1445  2022-07-02T08:55:38.327Z
# 4                7556          3621        9433  2022-07-02T08:55:38.327Z
# 5                 332          4128        6055  2022-07-02T08:55:38.327Z
# 6                7160          3454        1969  2022-07-02T08:55:38.327Z
# 7                7132          8470        4284  2022-07-02T08:55:38.327Z
# 8                6592          6284        8625  2022-07-02T08:55:38.327Z
# 9                1451          4399        2254  2022-07-02T08:55:38.327Z
#
#                  date_added  \
# 0  2022-07-02T08:55:38.327Z
# 1  2022-07-02T08:55:38.327Z
# 2  2022-07-02T08:55:38.327Z
# 3  2022-07-02T08:55:38.327Z
# 4  2022-07-02T08:55:38.327Z
# 5  2022-07-02T08:55:38.327Z
# 6  2022-07-02T08:55:38.327Z
# 7  2022-07-02T08:55:38.327Z
# 8  2022-07-02T08:55:38.327Z
# 9  2022-07-02T08:55:38.327Z
#
#                                                 tags platform  \
# 0  [f2lll1dtp9n, 9qxkl5124ph, zmqqzizd6mr, uqthy2...     None
# 1  [yxox3fsoqk, hpg6c7fpujd, bfgsth3snru, axtq54h...     None
# 2  [9diq91e7xzo, 4nygqxtlyk, g04nyj8fgdc, 6iquu0r...     None
# 3  [uzju3udc8f, wewj4bweuk, 35a782eh2z5, mkef66ox...     None
# 4  [jdbhpwy8vod, mgxl7z7u8zg, nisqbs4c8t, n5ttr3p...     None
# 5  [u8yfl64cbue, 5l0y4oi376h, fhemat7aipb, xsuefw...     None
# 6  [dattyiaxjdj, n42376phbrp, m7kwqx1386, wkyg0kv...     None
# 7  [ztk01esui4b, ynxj7s9vi6g, ggpih64348k, m649nm...     None
# 8  f4s9j227s, aynzinxmkjt, cux2hzwegxk, 6qs8q9...     None
# 9  [wtc0bb6ah9c, x4fso1s2bf, a6ixtiobyuc, 5mak017...     None
#
#   self_reported_circulating_supply self_reported_market_cap  \
# 0                             None                     None
# 1                             None                     None
# 2                             None                     None
# 3                             None                     None
# 4                             None                     None
# 5                             None                     None
# 6                             None                     None
# 7                             None                     None
# 8                             None                     None
# 9                             None                     None
#
#                                                quote
# 0  {'USD': {'price': 0.7142219870244, 'volume_24h...
# 1  {'USD': {'price': 0.554097915613877, 'volume_2...
# 2  {'USD': {'price': 0.2240120545357196, 'volume_...
# 3  {'USD': {'price': 0.7659518571431769, 'volume_...
# 4  {'USD': {'price': 0.17548236100159498, 'volume...
# 5  {'USD': {'price': 0.36047516476214314, 'volume...
# 6  {'USD': {'price': 0.28043377281563364, 'volume...
# 7  {'USD': {'price': 0.8179512722971185, 'volume_...
# 8  {'USD': {'price': 0.3083194361762296, 'volume_...
# 9  {'USD': {'price': 0.46716752852098953, 'volume...
