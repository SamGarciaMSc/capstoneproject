# %%
# Standard imports
import numpy as np
import pandas as pd

# For web scraping
import requests
from bs4 import BeautifulSoup

# For performing regex operations
import re

# For adding delays so that we don't spam requests
import time

# %%
# Save the URL of the webpage we want to scrape to a variable
url = 'https://api.spotify.com/v1/track/6rqhFgbbKwnb9MLmUQDhG6'

# %%
# Send a get request and assign the response to a variable
response = requests.get(url)

# %%
response.content
# Out:
# b'{\n  "error": {\n    "status": 401,\n    "message": "No token provided"\n  }\n}'

# %%
soup = BeautifulSoup(response.content)

# %%
# check contents of BeautifulSoup object
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="mobile-web-player" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Speak To Me - 2011 Remastered Version - song by Pink Floyd | Spotify
#   </title>
#   <meta content="Listen to Speak To Me - 2011 Remastered Version on Spotify. Pink Floyd · Song · 1973." name="description"/>
#   <meta content="notranslate" property="google"/>
#   <meta content="174829003346" property="fb:app_id"/>
#   <meta content="Speak To Me - 2011 Remastered Version" property="og:title"/>
#   <meta content="Pink Floyd · Song · 1973" property="og:description"/>
#   <meta content="https://open.spotify.com/track/4rQYDXfKFikLX4ad674jhg" property="og:url"/>
#   <meta content="https://i.scdn.co/image/ab67616d0000b27305d4eec40a828850aa8cd2f7" property="og:image"/>
#   <meta content="music.song" property="og:type"/>
#   <meta content="Spotify" property="og:site_name"/>
#   <meta content="https://p.scdn.co/mp3-preview/fb7faa72392973a5919aac291172b21aa2f8e331?cid=162b7dc01f3a4a2ca32ed3cec83d1e02&amp;utm_medium=facebook" property="og:audio"/>
#   <meta content="audio/vnd.facebook.bridge" property="og:audio:type"/>
#   <meta content="http://p.scdn.co/mp3-preview/fb7faa72392973a5919aac291172b21aa2f8e331?cid=162b7dc01f3a4a2ca32ed3cec83d1e02" property="music:preview_url:url"/>
#   <meta content="https://p.scdn.co/mp3-preview/fb7faa72392973a5919aac291172b21aa2f8e331?cid=162b7dc01f3a4a2ca32ed3cec83d1e02" property="music:preview_url:secure_url"/>
#   <meta content="audio/mpeg" property="music:preview_url:type"/>
#   <meta content="https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9" property="music:musician"/>
#   <meta content="64" property="music:duration"/>
#   <meta content="https://open.spotify.com/album/3a0UOgDWw2pTajw85QPMiz" property="music:album"/>
#   <meta content="1" property="music:album:track"/>
#   <meta content="1973-03-16" property="music:release_date"/>
#   <meta content="Spotify" property="al:android:app_name"/>
#   <meta content="com.spotify.music" property="al:android:package"/>
#   <meta content="spotify://track/4rQYDXfKFikLX4ad674jhg" property="al:android:url"/>
#   <meta content="Spotify" property="al:ios:app_name"/>
#   <meta content="324684580" property="al:ios:app_store_id"/>
#   <meta content="spotify://track/4rQYDXfKFikLX4ad674jhg" property="al:ios:url"/>
#   <meta content="@spotify" property="twitter:site"/>
#   <meta content="Speak To Me - 2011 Remastered Version" property="twitter:title"/>
#   <meta content="Pink Floyd · Song · 1973" property="twitter:description"/>
#   <meta content="https://i.scdn.co/image/ab67616d0000b27305d4eec40a828850aa8cd2f7" property="twitter:image"/>
#   <meta content="summary" property="twitter:card"/>
#   <link href="https://open.spotify.com/track/4rQYDXfKFikLX4ad674jhg" rel="canonical"/>
#   <link href="https://open.spotify.com/oembed?url=https%3A%2F%2Fopen.spotify.com%2Ftrack%2F4rQYDXfKFikLX4ad674jhg" rel="alternate" type="application/json+oembed"/>
#   <link href="android-app://com.spotify.music/spotify/track/4rQYDXfKFikLX4ad674jhg" rel="alternate"/>
#   <script type="application/ld+json">
#    {"@context":"http://schema.googleapis.com/","@type":"MusicRecording","@id":"https://open.spotify.com/track/4rQYDXfKFikLX4ad674jhg","url":"https://open.spotify.com/track/4rQYDXfKFikLX4ad674jhg","name":"Speak To Me - 2011 Remastered Version","description":"Listen to Speak To Me - 2011 Remastered Version on Spotify. Pink Floyd \u00B7 Song \u00B7 1973.","datePublished":"1973-03-16","potentialAction":{"@type":"ListenAction","target":[{"@type":"EntryPoint","urlTemplate":"https://open.spotify.com/track/4rQYDXfKFikLX4ad674jhg?autoplay=true","actionPlatform":["http://schema.org/DesktopWebPlatform","http://schema.org/IOSPlatform","http://schema.googleapis.com/GoogleAudioCast","http://schema.googleapis.com/GoogleVideoCast"]},"android-app://com.spotify.music/spotify/track/4rQYDXfKFikLX4ad674jhg/play"],"expectsAcceptanceOf":{"@type":"Offer","category":"free","eligibleRegion":[]}}}
#   </script>
#   <link href="https://open.spotifycdn.com/cdn/images/favicon32.8e66b099.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://open.spotifycdn.com/cdn/images/favicon16.c498a969.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://open.spotifycdn.com/cdn/images/favicon.5cb2bd30.ico" rel="icon"/>
#   <style data-styled="active">
#   </style>
#   <style data-styled="true" data-styled-version="5.3.5">
#    .laSmdK{fill:var(--text-base,#000000);}/*!sc*/
# .laSmdK *{vector-effect:non-scaling-stroke;}/*!sc*/
# .EQkJl{fill:currentColor;}/*!sc*/
# .EQkJl *{vector-effect:non-scaling-stroke;}/*!sc*/
# data-styled.g2[id="Svg-sc-1bi12j5-0"]{content:"laSmdK,EQkJl,"}/*!sc*/
# .djJRTA{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;font-size:14px;line-height:20px;font-weight:700;background-color:transparent;border:0;border-radius:500px;display:inline-block;position:relative;text-align:center;-webkit-text-decoration:none;text-decoration:none;text-transform:none;touch-action:manipulation;-webkit-transition-duration:33ms;transition-duration:33ms;-webkit-transition-property:background-color,border-color,color,box-shadow,filter,-webkit-transform;-webkit-transition-property:background-color,border-color,color,box-shadow,filter,transform;transition-property:background-color,border-color,color,box-shadow,filter,transform;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);color:var(--text-base,#000000);min-inline-size:0;padding-block-start:12px;padding-block-end:12px;padding-inline-start:12px;padding-inline-end:12px;}/*!sc*/
# @media (min-width:768px){.djJRTA{font-size:14px;line-height:20px;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .djJRTA:hover{-webkit-transform:scale(1.04);-ms-transform:scale(1.04);transform:scale(1.04);}/*!sc*/
# .djJRTA:active{opacity:0.7;outline:none;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);color:var(--text-subdued,#6a6a6a);}/*!sc*/
# .djJRTA::after{inline-size:24px;}/*!sc*/
# .djJRTA[disabled],.djJRTA[aria-disabled='true'],fieldset[disabled] .djJRTA{cursor:not-allowed;opacity:0.3;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);color:var(--text-subdued,#6a6a6a);}/*!sc*/
# .djJRTA[disabled]::before,.djJRTA[aria-disabled='true']::before,fieldset[disabled] .djJRTA::before{background-color:transparent;}/*!sc*/
# .djJRTA[disabled]::after,.djJRTA[aria-disabled='true']::after,fieldset[disabled] .djJRTA::after{border-color:transparent;}/*!sc*/
# .eIVsbB{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;font-size:11px;line-height:16px;font-weight:700;background-color:transparent;border:0;border-radius:500px;display:inline-block;position:relative;text-align:center;-webkit-text-decoration:none;text-decoration:none;text-transform:none;touch-action:manipulation;-webkit-transition-duration:33ms;transition-duration:33ms;-webkit-transition-property:background-color,border-color,color,box-shadow,filter,-webkit-transform;-webkit-transition-property:background-color,border-color,color,box-shadow,filter,transform;transition-property:background-color,border-color,color,box-shadow,filter,transform;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);color:var(--text-base,#000000);min-inline-size:0;padding-block-start:8px;padding-block-end:8px;padding-inline-start:8px;padding-inline-end:8px;}/*!sc*/
# @media (min-width:768px){.eIVsbB{font-size:11px;line-height:16px;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .eIVsbB:hover{-webkit-transform:scale(1.04);-ms-transform:scale(1.04);transform:scale(1.04);}/*!sc*/
# .eIVsbB:active{opacity:0.7;outline:none;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);color:var(--text-subdued,#6a6a6a);}/*!sc*/
# .eIVsbB::after{inline-size:16px;}/*!sc*/
# .eIVsbB[disabled],.eIVsbB[aria-disabled='true'],fieldset[disabled] .eIVsbB{cursor:not-allowed;opacity:0.3;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);color:var(--text-subdued,#6a6a6a);}/*!sc*/
# .eIVsbB[disabled]::before,.eIVsbB[aria-disabled='true']::before,fieldset[disabled] .eIVsbB::before{background-color:transparent;}/*!sc*/
# .eIVsbB[disabled]::after,.eIVsbB[aria-disabled='true']::after,fieldset[disabled] .eIVsbB::after{border-color:transparent;}/*!sc*/
# .kyVmlV{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;font-size:11px;line-height:16px;font-weight:700;background-color:transparent;border:0;border-radius:500px;display:inline-block;position:relative;text-align:center;-webkit-text-decoration:none;text-decoration:none;text-transform:none;touch-action:manipulation;-webkit-transition-duration:33ms;transition-duration:33ms;-webkit-transition-property:background-color,border-color,color,box-shadow,filter,-webkit-transform;-webkit-transition-property:background-color,border-color,color,box-shadow,filter,transform;transition-property:background-color,border-color,color,box-shadow,filter,transform;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);color:var(--text-subdued,#6a6a6a);min-inline-size:0;padding-block-start:8px;padding-block-end:8px;padding-inline-start:0;padding-inline-end:0;}/*!sc*/
# @media (min-width:768px){.kyVmlV{font-size:11px;line-height:16px;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .kyVmlV:hover{-webkit-transform:scale(1.04);-ms-transform:scale(1.04);transform:scale(1.04);color:var(--text-base,#000000);}/*!sc*/
# .kyVmlV:active{opacity:0.7;outline:none;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);color:var(--text-subdued,#6a6a6a);}/*!sc*/
# .kyVmlV::after{inline-size:16px;}/*!sc*/
# .kyVmlV[disabled],.kyVmlV[aria-disabled='true'],fieldset[disabled] .kyVmlV{cursor:not-allowed;opacity:0.3;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);color:var(--text-subdued,#6a6a6a);}/*!sc*/
# .kyVmlV[disabled]::before,.kyVmlV[aria-disabled='true']::before,fieldset[disabled] .kyVmlV::before{background-color:transparent;}/*!sc*/
# .kyVmlV[disabled]::after,.kyVmlV[aria-disabled='true']::after,fieldset[disabled] .kyVmlV::after{border-color:transparent;}/*!sc*/
# data-styled.g4[id="Button-sc-1dqy6lx-0"]{content:"djJRTA,eIVsbB,kyVmlV,"}/*!sc*/
# .bxwPwV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g5[id="IconWrapper__Wrapper-sc-16usrgb-0"]{content:"bxwPwV,"}/*!sc*/
# .cMxxrg{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:2rem;line-height:2.25rem;-webkit-letter-spacing:-0.04em;-moz-letter-spacing:-0.04em;-ms-letter-spacing:-0.04em;letter-spacing:-0.04em;font-weight:700;color:inherit;}/*!sc*/
# @media (min-width:768px){.cMxxrg{font-size:2rem;line-height:2.25rem;text-transform:none;-webkit-letter-spacing:-0.04em;-moz-letter-spacing:-0.04em;-ms-letter-spacing:-0.04em;letter-spacing:-0.04em;}}/*!sc*/
# .ebHsEf{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:0.8125rem;line-height:1rem;font-weight:400;color:inherit;}/*!sc*/
# @media (min-width:768px){.ebHsEf{font-size:0.875rem;line-height:1rem;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .dhAODk{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:0.625rem;line-height:1rem;text-transform:uppercase;-webkit-letter-spacing:0.1em;-moz-letter-spacing:0.1em;-ms-letter-spacing:0.1em;letter-spacing:0.1em;font-weight:700;color:inherit;}/*!sc*/
# @media (min-width:768px){.dhAODk{font-size:0.75rem;line-height:1rem;text-transform:uppercase;-webkit-letter-spacing:0.1em;-moz-letter-spacing:0.1em;-ms-letter-spacing:0.1em;letter-spacing:0.1em;}}/*!sc*/
# .edDNNU{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:1rem;line-height:1.5rem;font-weight:700;color:inherit;}/*!sc*/
# @media (min-width:768px){.edDNNU{font-size:1rem;line-height:1.5rem;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .cWJaoY{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:1.125rem;line-height:1.5rem;font-weight:700;color:inherit;}/*!sc*/
# @media (min-width:768px){.cWJaoY{font-size:1.125rem;line-height:1.5rem;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .loEuIb{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:0.6875rem;line-height:1rem;font-weight:400;color:inherit;}/*!sc*/
# @media (min-width:768px){.loEuIb{font-size:0.6875rem;line-height:1rem;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .fRjWay{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:0.8125rem;line-height:1rem;font-weight:700;padding-block-end:8px;color:inherit;}/*!sc*/
# @media (min-width:768px){.fRjWay{font-size:0.875rem;line-height:1rem;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .cpSTHq{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:0.6875rem;line-height:1rem;font-weight:400;color:var(--text-subdued,#6a6a6a);}/*!sc*/
# @media (min-width:768px){.cpSTHq{font-size:0.6875rem;line-height:1rem;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .iaEwFO{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:1rem;line-height:1.5rem;font-weight:400;color:var(--text-subdued,#6a6a6a);}/*!sc*/
# @media (min-width:768px){.iaEwFO{font-size:1rem;line-height:1.5rem;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .gAmaez{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;margin-block-start:0;margin-block-end:0;font-size:1rem;line-height:1.5rem;font-weight:400;color:inherit;}/*!sc*/
# @media (min-width:768px){.gAmaez{font-size:1rem;line-height:1.5rem;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# data-styled.g8[id="Type__TypeElement-goli3j-0"]{content:"cMxxrg,ebHsEf,dhAODk,edDNNU,cWJaoY,loEuIb,fRjWay,cpSTHq,iaEwFO,gAmaez,"}/*!sc*/
# .gHYQaG{position:relative;background-color:var(--background-base,#1ed760);color:var(--text-base,#000000);border-radius:500px;font-size:inherit;inline-size:56px;-webkit-block-size:56px;-ms-flex-block-size:56px;block-size:56px;}/*!sc*/
# data-styled.g32[id="ButtonInner-sc-14ud5tc-0"]{content:"gHYQaG,"}/*!sc*/
# .eFVhex{box-sizing:border-box;font-family:var(--font-family,spotify-circular),Helvetica,Arial,sans-serif;-webkit-tap-highlight-color:transparent;font-size:16px;line-height:24px;font-weight:700;background-color:transparent;border:0;border-radius:500px;display:inline-block;position:relative;text-align:center;-webkit-text-decoration:none;text-decoration:none;text-transform:none;touch-action:manipulation;-webkit-transition-duration:33ms;transition-duration:33ms;-webkit-transition-property:background-color,border-color,color,box-shadow,filter,-webkit-transform;-webkit-transition-property:background-color,border-color,color,box-shadow,filter,transform;transition-property:background-color,border-color,color,box-shadow,filter,transform;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);padding:0;min-inline-size:0;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;}/*!sc*/
# @media (min-width:768px){.eFVhex{font-size:16px;line-height:24px;text-transform:none;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}}/*!sc*/
# .eFVhex:hover .ButtonInner-sc-14ud5tc-0,.eFVhex:hover .ButtonFocus-sc-2hq6ey-0{-webkit-transform:scale(1.04);-ms-transform:scale(1.04);transform:scale(1.04);}/*!sc*/
# .eFVhex:hover .ButtonInner-sc-14ud5tc-0{background-color:var(--background-highlight,#1fdf64);}/*!sc*/
# .eFVhex:active .ButtonInner-sc-14ud5tc-0{background-color:var(--background-press,#169c46);box-shadow:none;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .eFVhex:active .ButtonFocus-sc-2hq6ey-0{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .eFVhex:focus .ButtonFocus-sc-2hq6ey-0{border-color:var(--essential-base,#000000);}/*!sc*/
# .eFVhex[disabled] .ButtonInner-sc-14ud5tc-0,.eFVhex[aria-disabled='true'] .ButtonInner-sc-14ud5tc-0,fieldset[disabled] .eFVhex .ButtonInner-sc-14ud5tc-0{cursor:not-allowed;opacity:0.3;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);background-color:var(--background-base,#1ed760);color:var(--text-base,#000000);}/*!sc*/
# .eFVhex[disabled] .ButtonFocus-sc-2hq6ey-0,.eFVhex[aria-disabled='true'] .ButtonFocus-sc-2hq6ey-0,fieldset[disabled] .eFVhex .ButtonFocus-sc-2hq6ey-0{border-color:transparent;}/*!sc*/
# data-styled.g33[id="Button-qlcn5g-0"]{content:"eFVhex,"}/*!sc*/
# .dZGDpi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:absolute;top:14px;left:14px;}/*!sc*/
# [dir='rtl'] .IconWrapper__Wrapper-sc-1hf1hjl-0{right:14px;left:auto;}/*!sc*/
# data-styled.g34[id="IconWrapper__Wrapper-sc-1hf1hjl-0"]{content:"dZGDpi,"}/*!sc*/
# .fJTbNO{fill:var(--text-base,#000000);stroke:transparent;}/*!sc*/
# data-styled.g235[id="Svg-sc-6c3c1v-0"]{content:"fJTbNO,"}/*!sc*/
# .iOMJwg{background:none;margin:0;border:none;color:#ffffff;text-align:start;padding:0;}/*!sc*/
# data-styled.g238[id="PreviewMenu__Button-sc-1rhumgb-2"]{content:"iOMJwg,"}/*!sc*/
# .hLfRGu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:6;margin-inline-start:16px;}/*!sc*/
# data-styled.g245[id="PreviewMenuButton__StyledIconButton-sc-ll4iws-0"]{content:"hLfRGu,"}/*!sc*/
# .dhTxyf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g246[id="PreviewMenuButton__PreviewWrapper-sc-ll4iws-1"]{content:"dhTxyf,"}/*!sc*/
# .HlJFj{display:block;height:100%;overflow-y:auto;overflow-x:hidden;position:relative;width:100%;-webkit-filter:blur( none );filter:blur( none );-webkit-transition:filter 0.2s;transition:filter 0.2s;z-index:none;}/*!sc*/
# data-styled.g247[id="RootLayer__Root-sc-1parc1f-0"]{content:"HlJFj,"}/*!sc*/
# .bWDBua{height:100%;}/*!sc*/
# data-styled.g248[id="RootLayer__Wrapper-sc-1parc1f-1"]{content:"bWDBua,"}/*!sc*/
# .dBlTZt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;min-height:100vh;padding-bottom:0px;}/*!sc*/
# data-styled.g249[id="RootLayer__RootChild-sc-1parc1f-2"]{content:"dBlTZt,"}/*!sc*/
# .jBGDHP{display:inline-block;font-size:12px;font-weight:700;-webkit-letter-spacing:1px;-moz-letter-spacing:1px;-ms-letter-spacing:1px;letter-spacing:1px;line-height:1;text-align:center;vertical-align:middle;padding:10px 24px;height:32px;white-space:pre;border-radius:500px;background:#fff;color:#000;text-overflow:ellipsis;overflow:hidden;border:none;text-transform:uppercase;}/*!sc*/
# .jBGDHP:hover{-webkit-transform:scale(0.98);-ms-transform:scale(0.98);transform:scale(0.98);opacity:0.9;}/*!sc*/
# data-styled.g262[id="LoginTopBar__OpenAppButton-sc-eyy3h1-0"]{content:"jBGDHP,"}/*!sc*/
# .bslrbW{height:56px;position:fixed;top:0;left:0;right:0;z-index:3;background-color:rgb();display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:16px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .bslrbW::before{content:'';position:absolute;z-index:-1;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,48%);}/*!sc*/
# .bslrbW svg{vertical-align:middle;}/*!sc*/
# data-styled.g263[id="LoginTopBar__TopBarWrapper-sc-eyy3h1-1"]{content:"bslrbW,"}/*!sc*/
# .gXeCSy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:auto;}/*!sc*/
# data-styled.g264[id="LoginTopBar__TopBarActionsContainer-sc-eyy3h1-2"]{content:"gXeCSy,"}/*!sc*/
# .eZqDgj{background:none;margin:0;padding:0 16px;border:none;}/*!sc*/
# data-styled.g265[id="LoginTopBar__IconButton-sc-eyy3h1-3"]{content:"eZqDgj,"}/*!sc*/
# *{box-sizing:border-box;}/*!sc*/
# html{height:100%;}/*!sc*/
# body{background-color:#121212;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;margin:0;-webkit-tap-highlight-color:rgba(255,255,255,0.1);}/*!sc*/
# body,input{font-family:'spotify-circular','spotify-circular-cyrillic','spotify-circular-arabic','spotify-circular-hebrew','Helvetica Neue',Helvetica,Arial,'Hiragino Kaku Gothic Pro','Meiryo','MS Gothic',sans-serif;font-size:16px;font-weight:700;line-height:24px;color:#ffffff;text-transform:none;}/*!sc*/
# a{color:#ffffff;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# a:hover,a:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# #main{z-index:0;width:100%;height:100%;}/*!sc*/
# .initial-render{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;color:#ffffff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;font-family:'spotify-circular','spotify-circular-cyrillic','spotify-circular-arabic','spotify-circular-hebrew','Helvetica Neue',Helvetica,Arial,'Hiragino Kaku Gothic Pro','Meiryo','MS Gothic',sans-serif;height:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;left:0;line-height:24px;padding:16px 16px 32px;position:fixed;text-align:center;text-transform:none;top:0;width:100%;}/*!sc*/
# .initial-render::before{background-image:linear-gradient(rgba(0,0,0,0.3),rgba(0,0,0,0.1));bottom:0;content:'';left:0;position:absolute;right:0;top:0;z-index:1;}/*!sc*/
# @-webkit-keyframes mwpFadeIn{0%{opacity:0;-webkit-transform:translate(0,20px);-ms-transform:translate(0,20px);transform:translate(0,20px);}100%{opacity:1;-webkit-transform:translate(0,0);-ms-transform:translate(0,0);transform:translate(0,0);}}/*!sc*/
# @keyframes mwpFadeIn{0%{opacity:0;-webkit-transform:translate(0,20px);-ms-transform:translate(0,20px);transform:translate(0,20px);}100%{opacity:1;-webkit-transform:translate(0,0);-ms-transform:translate(0,0);transform:translate(0,0);}}/*!sc*/
# .mwp-fade-in{-webkit-animation:mwpFadeIn ease-in 0.2s forwards;animation:mwpFadeIn ease-in 0.2s forwards;opacity:0;}/*!sc*/
# .mwp-fade-in--one{-webkit-animation-delay:0.7s;animation-delay:0.7s;}/*!sc*/
# .mwp-fade-in--two{-webkit-animation-delay:0.8s;animation-delay:0.8s;}/*!sc*/
# .mwp-fade-in--three{-webkit-animation-delay:0.9s;animation-delay:0.9s;}/*!sc*/
# [class^='spoticon-']::before,[class*=' spoticon-']::before{font-family:'glue1-spoticon';font-style:normal;font-weight:normal;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;line-height:inherit;vertical-align:bottom;display:inline-block;-webkit-text-decoration:inherit;text-decoration:inherit;}/*!sc*/
# .spoticon-x-16::before{content:'F160';font-size:16px;}/*!sc*/
# .logo:hover{-webkit-text-decoration:none;text-decoration:none;border-color:transparent;}/*!sc*/
# .logo svg{height:32px;width:32px;}/*!sc*/
# @-webkit-keyframes loading{0%{-webkit-animation-timing-function:cubic-bezier(1,0,0.7,1);animation-timing-function:cubic-bezier(1,0,0.7,1);opacity:0.5;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}40%{-webkit-animation-timing-function:cubic-bezier(0.3,0,0,1);animation-timing-function:cubic-bezier(0.3,0,0,1);opacity:0.75;-webkit-transform:scale(1.3);-ms-transform:scale(1.3);transform:scale(1.3);}72.5%{-webkit-animation-timing-function:linear;animation-timing-function:linear;opacity:0.5;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}100%{opacity:0.5;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}/*!sc*/
# @keyframes loading{0%{-webkit-animation-timing-function:cubic-bezier(1,0,0.7,1);animation-timing-function:cubic-bezier(1,0,0.7,1);opacity:0.5;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}40%{-webkit-animation-timing-function:cubic-bezier(0.3,0,0,1);animation-timing-function:cubic-bezier(0.3,0,0,1);opacity:0.75;-webkit-transform:scale(1.3);-ms-transform:scale(1.3);transform:scale(1.3);}72.5%{-webkit-animation-timing-function:linear;animation-timing-function:linear;opacity:0.5;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}100%{opacity:0.5;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}/*!sc*/
# .loader{height:12px;width:56px;}/*!sc*/
# .loader circle{fill:#ffffff;-webkit-animation:loading 1.32s linear infinite;animation:loading 1.32s linear infinite;-webkit-transform-origin:center;-ms-transform-origin:center;transform-origin:center;}/*!sc*/
# .loader circle:nth-of-type(2){-webkit-animation-delay:0.1s;animation-delay:0.1s;}/*!sc*/
# .loader circle:nth-of-type(3){-webkit-animation-delay:0.2s;animation-delay:0.2s;}/*!sc*/
# data-styled.g341[id="sc-global-bzdggc1"]{content:"sc-global-bzdggc1,"}/*!sc*/
# .cFevRz{isolation:isolate;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g342[id="App__MainContent-sc-hckv0t-0"]{content:"cFevRz,"}/*!sc*/
# .gxaSIL{display:block;height:100%;width:100%;position:fixed;top:0;left:0;z-index:6;pointer-events:none;}/*!sc*/
# .gxaSIL *{pointer-events:all;}/*!sc*/
# data-styled.g343[id="App__ModalLayer-sc-hckv0t-1"]{content:"gxaSIL,"}/*!sc*/
#   </style>
#   <link href="https://open.spotifycdn.com/cdn/build/mwp/mwp-artist-page.2a0edad7.css" rel="stylesheet"/>
#   <link href="https://open.spotifycdn.com/cdn/build/mwp/mwp-dialog-container.7a143291.css" rel="stylesheet"/>
#   <link href="https://open.spotifycdn.com/cdn/build/mwp/mwp.3662e424.css" rel="stylesheet"/>
#   <script data-testid="config" id="config" type="application/json">
#    {"clientId":"e8832","accessToken":"BQCoTB0GMuec4hZAELhfUjdYrs6QNMj_y1R46pGprK2bqjfy8_5bklW90zH586X1qhMHlaZLXGU6tY6jpLgz-IOE39eip3eRcNgmuAPQlo0Cc-tWMGE","accessTokenExpirationTimestampMs":1656604313453,"isAnonymous":true,"app_name":"web_player_prototype","market":"GB","locale":{"locale":"en","rtl":false,"textDirection":"ltr"},"gtmId":"GTM-PZHN3VD","optimizeId":"GTM-W53X654","userCountry":null,"isPremium":false,"correlationId":"c0c33a2d2e4770182a16213a83e17f96","retargetingPixels":{"twitter":"o0fpx","pinterest":"2613898645044","snapchat":"38d8444a-feca-4a00-8ce8-24c20d195d67"}}
#   </script>
#   <script id="baba" type="application/json">
#    [{"id":"x2zAbdkZToO1ZlMRauDXjA","variant":"1"}]
#   </script>
#   <script defer="" src="https://open.spotifycdn.com/cdn/js/retargeting-pixels.1fa1ceda.js">
#   </script>
#   <script defer="" src="https://www.googleoptimize.com/optimize.js?id=GTM-W53X654">
#   </script>
#   <script defer="" src="https://open.spotifycdn.com/cdn/js/gtm.7dc32ad7.js">
#   </script>
#   <link crossorigin="anonymous" href="https://api.spotify.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://apresolve.spotify.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://daily-mix.scdn.co" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://exp.wg.spotify.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://gew1-dealer.spotify.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://gew1-spclient.spotify.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://i.scdn.co" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://lineup-images.scdn.co" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://mosaic.scdn.co" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://open.spotifycdn.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://pixel-static.spotify.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://pixel.spotify.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://pl.scdn.co" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://spclient.wg.spotify.com" rel="preconnect"/>
#   <link as="font" crossorigin="anonymous" href="https://open.spotifycdn.com/cdn/fonts/CircularSpUIv3T-Book.3466e0ec.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://open.spotifycdn.com/cdn/fonts/CircularSpUIv3T-Bold.8d0a45cc.woff2" rel="preload" type="font/woff2"/>
#   <link as="fetch" crossorigin="anonymous" data-translations-url-for-locale="en" href="https://open.spotifycdn.com/cdn/generated-locales/mwp/en.d633de3c.json" rel="preload" type="application/json"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link as="script" href="https://open.spotifycdn.com/cdn/build/mwp/vendor~mwp.03eae2cd.js" rel="preload"/>
#   <link as="script" href="https://open.spotifycdn.com/cdn/build/mwp/mwp.7bffc06c.js" rel="preload"/>
#   <link href="https://open.spotifycdn.com/cdn/generated/opensearch.b0a1be42.xml" rel="search" title="Spotify" type="application/opensearchdescription+xml"/>
#  </head>
#  <body class="mobile-web-player" data-locale="en" data-market="GB">
#   <div data-ssr="1" id="main">
#    <div class="RootLayer__Wrapper-sc-1parc1f-1 bWDBua">
#     <div class="RootLayer__Root-sc-1parc1f-0 HlJFj encore-dark-theme" data-main-scrollable-node="true">
#      <div class="RootLayer__RootChild-sc-1parc1f-2 dBlTZt">
#       <div class="App__MainContent-sc-hckv0t-0 cFevRz">
#        <div class="WMpyFi3Bsivm043uWd4E" data-testid="track-view">
#         <div class="vdbEE_aZ_w6hwyZ0U1Qr">
#          <div class="LoginTopBar__TopBarWrapper-sc-eyy3h1-1 bslrbW">
#           <a aria-current="page" class="active" draggable="false" href="/">
#            <svg aria-hidden="false" aria-label="Spotify" class="Svg-sc-6c3c1v-0 fJTbNO" data-testid="spotify-icon" height="32" role="img" viewbox="0 0 26 24">
#             <title>
#              Spotify
#             </title>
#             <path d="M18.616 10.639c-3.77-2.297-9.99-2.509-13.59-1.388a1.077 1.077 0 0 1-1.164-.363 1.14 1.14 0 0 1-.119-1.237c.136-.262.37-.46.648-.548 4.132-1.287 11-1.038 15.342 1.605a1.138 1.138 0 0 1 .099 1.863 1.081 1.081 0 0 1-.813.213c-.142-.02-.28-.07-.403-.145Zm-.124 3.402a.915.915 0 0 1-.563.42.894.894 0 0 1-.69-.112c-3.144-1.983-7.937-2.557-11.657-1.398a.898.898 0 0 1-.971-.303.952.952 0 0 1-.098-1.03.929.929 0 0 1 .54-.458c4.248-1.323 9.53-.682 13.14 1.595a.95.95 0 0 1 .3 1.286Zm-1.43 3.267a.73.73 0 0 1-.45.338.712.712 0 0 1-.553-.089c-2.748-1.722-6.204-2.111-10.276-1.156a.718.718 0 0 1-.758-.298.745.745 0 0 1-.115-.265.757.757 0 0 1 .092-.563.737.737 0 0 1 .457-.333c4.455-1.045 8.277-.595 11.361 1.338a.762.762 0 0 1 .241 1.028ZM11.696 0C5.237 0 0 5.373 0 12c0 6.628 5.236 12 11.697 12 6.46 0 11.698-5.372 11.698-12 0-6.627-5.238-12-11.699-12h.001Zm20.126 11.078c-2.019-.494-2.379-.84-2.379-1.57 0-.688.633-1.151 1.572-1.151.91 0 1.814.352 2.76 1.076a.131.131 0 0 0 .187-.03l.987-1.426a.139.139 0 0 0-.025-.185c-1.127-.928-2.396-1.378-3.88-1.378-2.18 0-3.703 1.342-3.703 3.263 0 2.06 1.315 2.788 3.585 3.352 1.932.457 2.258.84 2.258 1.524 0 .757-.659 1.229-1.72 1.229-1.18 0-2.141-.408-3.216-1.364a.13.13 0 0 0-.188.016l-1.106 1.35a.137.137 0 0 0 .013.188c1.252 1.147 2.79 1.752 4.451 1.752 2.35 0 3.869-1.317 3.869-3.356 0-1.723-1.003-2.676-3.465-3.29Zm10.487 2.31c0 1.454-.874 2.47-2.125 2.47-1.235 0-2.169-1.061-2.169-2.47 0-1.41.933-2.47 2.17-2.47 1.23 0 2.124 1.038 2.124 2.47Zm-1.706-4.354c-1.018 0-1.854.412-2.543 1.256v-.95a.136.136 0 0 0-.038-.095.132.132 0 0 0-.093-.04h-1.81a.131.131 0 0 0-.093.04.136.136 0 0 0-.039.096v10.546c0 .076.06.137.133.137h1.809a.132.132 0 0 0 .093-.041.136.136 0 0 0 .038-.096v-3.329c.69.794 1.525 1.18 2.543 1.18 1.893 0 3.808-1.494 3.808-4.35 0-2.858-1.915-4.354-3.808-4.354Zm8.72 6.839c-1.297 0-2.274-1.068-2.274-2.486 0-1.422.943-2.455 2.244-2.455 1.305 0 2.288 1.069 2.288 2.487 0 1.422-.949 2.454-2.258 2.454Zm0-6.838c-2.438 0-4.347 1.926-4.347 4.383 0 2.432 1.896 4.338 4.317 4.338 2.445 0 4.36-1.92 4.36-4.369 0-2.44-1.901-4.353-4.33-4.353Zm9.535.17h-1.99V7.117a.136.136 0 0 0-.08-.126.13.13 0 0 0-.052-.01h-1.809a.133.133 0 0 0-.093.04.136.136 0 0 0-.038.095v2.087h-.87a.131.131 0 0 0-.122.085.139.139 0 0 0-.01.052v1.595c0 .074.06.135.132.135h.87v4.126c0 1.667.809 2.513 2.404 2.513.648 0 1.186-.138 1.694-.434a.135.135 0 0 0 .067-.117V15.64a.137.137 0 0 0-.063-.115.13.13 0 0 0-.129-.006c-.349.18-.685.263-1.061.263-.58 0-.84-.271-.84-.876V11.07h1.99a.13.13 0 0 0 .094-.04.136.136 0 0 0 .039-.096V9.339a.137.137 0 0 0-.039-.096.132.132 0 0 0-.094-.04v.001Zm6.934.007v-.255c0-.755.281-1.092.914-1.092.376 0 .68.077 1.019.194a.13.13 0 0 0 .118-.02.135.135 0 0 0 .056-.11V6.365a.137.137 0 0 0-.026-.081.133.133 0 0 0-.068-.05 4.852 4.852 0 0 0-1.502-.22c-1.67 0-2.554.965-2.554 2.788v.393h-.87a.132.132 0 0 0-.093.04.136.136 0 0 0-.038.096v1.603c0 .075.059.136.132.136h.87v6.364c0 .075.058.135.131.135h1.809c.072 0 .131-.06.131-.135V11.07h1.69l2.586 6.362c-.294.669-.583.802-.977.802-.319 0-.654-.098-.998-.29a.133.133 0 0 0-.105-.01.135.135 0 0 0-.078.072l-.612 1.38a.137.137 0 0 0 .056.175 3.733 3.733 0 0 0 1.932.508c1.334 0 2.073-.638 2.724-2.355l3.137-8.317a.14.14 0 0 0-.014-.126.131.131 0 0 0-.108-.06h-1.883a.132.132 0 0 0-.126.092l-1.928 5.651L69.006 9.3a.133.133 0 0 0-.124-.088h-3.09v.001Zm-4.02-.008h-1.809a.132.132 0 0 0-.093.041.136.136 0 0 0-.038.096v8.094c0 .075.06.135.132.135h1.809c.072 0 .131-.06.131-.135V9.34a.136.136 0 0 0-.038-.096.133.133 0 0 0-.094-.04Zm-.896-3.685a1.295 1.295 0 0 0-.919.393c-.243.25-.379.586-.377.937a1.342 1.342 0 0 0 .377.938 1.304 1.304 0 0 0 .92.393c.346-.002.677-.143.92-.393s.379-.587.377-.938c0-.735-.581-1.33-1.296-1.33h-.002Zm15.918 4.49h-.331v.434h.331c.165 0 .264-.083.264-.216 0-.142-.099-.217-.264-.217Zm.215.619.36.517h-.304l-.323-.474h-.279v.474h-.254v-1.37h.595c.31 0 .515.163.515.436a.412.412 0 0 1-.31.417Zm-.282-1.31c-.652 0-1.146.532-1.146 1.183 0 .65.49 1.175 1.139 ...
#             </path>
#            </svg>
#           </a>
#           <div class="LoginTopBar__TopBarActionsContainer-sc-eyy3h1-2 gXeCSy">
#            <button aria-label="Search" class="LoginTopBar__IconButton-sc-eyy3h1-3 eZqDgj">
#             <svg class="Svg-sc-1bi12j5-0 laSmdK" height="16" role="img" viewbox="0 0 16 16" width="16">
#              <path d="M7 1.75a5.25 5.25 0 100 10.5 5.25 5.25 0 000-10.5zM.25 7a6.75 6.75 0 1112.096 4.12l3.184 3.185a.75.75 0 11-1.06 1.06L11.304 12.2A6.75 6.75 0 01.25 7z">
#              </path>
#             </svg>
#            </button>
#            <button class="LoginTopBar__OpenAppButton-sc-eyy3h1-0 jBGDHP" data-testid="open-app-button" version="secondary">
#             Open App
#            </button>
#            <div class="PreviewMenuButton__PreviewWrapper-sc-ll4iws-1 dhTxyf" id="preview-menu-container">
#             <button aria-controls="preview-menu" aria-expanded="false" aria-haspopup="true" aria-label="Menu" class="PreviewMenu__Button-sc-1rhumgb-2 PreviewMenuButton__StyledIconButton-sc-ll4iws-0 iOMJwg hLfRGu" data-testid="preview-menu-button" id="preview-menu-button" style="visibility:visible">
#              <svg class="Svg-sc-1bi12j5-0 laSmdK" height="24" role="img" viewbox="0 0 24 24" width="24">
#               <path d="M21 6H3V4h18v2zm0 14H3v-2h18v2zm0-7H3v-2h18v2z">
#               </path>
#              </svg>
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="FW5sqOvxnFBPlL0aZpQU" data-testid="header" style="background-color:#22893E;background:linear-gradient(#22893E 0%, transparent 100%)">
#           <div class="OTu6i7id2mUIo8sMJJMh">
#            <div class="vreceNX3ABcxyddeS83B" style="width:152px;height:152px">
#             <img alt="Speak To Me - 2011 Remastered Version" aria-hidden="true" class="mMx2LUixlnN_Fu45JpFB iJp40IxKg6emF6KYJ414 CxurIfvXVb_TqGF4q8Yf H71KtIrytVayf_dFofu7" data-testid="entity-image" draggable="false" loading="eager" src="https://i.scdn.co/image/ab67616d0000b27305d4eec40a828850aa8cd2f7" srcset="https://i.scdn.co/image/ab67616d0000b27305d4eec40a828850aa8cd2f7 5w, https://i.scdn.co/image/ab67616d0000b27305d4eec40a828850aa8cd2f7 10w"/>
#            </div>
#           </div>
#           <div class="mbp0yoQohl2E9PzJ9uAy">
#            <h2 class="YTjXXuWGIV3Yo4gJ4HsA o1sGwtZzq4i1QlWRP_zH" style="opacity:0.5">
#             Song
#            </h2>
#            <span class="JmV8FMNND0hJM4fCS9E4" dir="auto">
#             <span class="Type__TypeElement-goli3j-0 cMxxrg V4vPzzVtMpFh2ZLTRD6H" data-testid="track-entity-title">
#              Speak To Me - 2011 Remastered Version
#             </span>
#            </span>
#            <div class="rS_2dJG9pgqS2A2BZ5rZ" data-testid="track-entity-metadata">
#             <div class="Type__TypeElement-goli3j-0 ebHsEf T3C0eBxRoJcpqMNCpLT6 FyfbzzWIE70wBv67eCsB" dir="auto">
#              Pink Floyd
#             </div>
#             <div class="Type__TypeElement-goli3j-0 ebHsEf T3C0eBxRoJcpqMNCpLT6">
#              1973
#             </div>
#             <div class="Type__TypeElement-goli3j-0 ebHsEf T3C0eBxRoJcpqMNCpLT6">
#              1:05
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="tf1HzruEG3U4rBoIj8Qy" data-testid="action-bar-container">
#           <div class="xa2Tw0jtHFfTafnM_dKx">
#            <div class="J0uVVo1DNKAgOxkKyjwO WuGxno6K1r4TIF3l6Wms">
#             <div class="apWuNqdW88AF4mPFvRSd">
#              <div class="PFgcCoJSWC3KjhZxHDYH">
#               <button aria-label="Play" class="Button-qlcn5g-0 eFVhex" data-testid="play-button">
#                <div class="ButtonInner-sc-14ud5tc-0 gHYQaG encore-bright-accent-set">
#                 <span aria-hidden="true" class="IconWrapper__Wrapper-sc-1hf1hjl-0 dZGDpi">
#                  <svg class="Svg-sc-1bi12j5-0 EQkJl" height="28" role="img" viewbox="0 0 24 24" width="28">
#                   <path d="M7.05 3.606l13.49 7.788a.7.7 0 010 1.212L7.05 20.394A.7.7 0 016 19.788V4.212a.7.7 0 011.05-.606z">
#                   </path>
#                  </svg>
#                 </span>
#                </div>
#               </button>
#              </div>
#             </div>
#             <span class="axpK8A1t0KtOmoPOFcbF">
#             </span>
#             <div class="lL7ZcEcJa_AA5P8GBsAX">
#              <button aria-checked="false" aria-label="Save to Your Library" class="Fm7C3gdh5Lsc9qSXrQwO" data-testid="add-button" role="switch" type="button">
#               <svg class="Svg-sc-1bi12j5-0 EQkJl" height="32" role="img" viewbox="0 0 24 24" width="32">
#                <path d="M5.21 1.57a6.757 6.757 0 016.708 1.545.124.124 0 00.165 0 6.741 6.741 0 015.715-1.78l.004.001a6.802 6.802 0 015.571 5.376v.003a6.689 6.689 0 01-1.49 5.655l-7.954 9.48a2.518 2.518 0 01-3.857 0L2.12 12.37A6.683 6.683 0 01.627 6.714 6.757 6.757 0 015.21 1.57zm3.12 1.803a4.757 4.757 0 00-5.74 3.725l-.001.002a4.684 4.684 0 001.049 3.969l.009.01 7.958 9.485a.518.518 0 00.79 0l7.968-9.495a4.688 4.688 0 001.049-3.965 4.803 4.803 0 00-3.931-3.794 4.74 4.74 0 00-4.023 1.256l-.008.008a2.123 2.123 0 01-2.9 0l-.007-.007a4.757 4.757 0 00-2.214-1.194z">
#                </path>
#               </svg>
#              </button>
#              <button aria-label="Open context menu" class="Button-sc-1dqy6lx-0 djJRTA aS0qlPeOyzTGzGVzlPQa" data-testid="context-menu-action">
#               <span aria-hidden="true" class="IconWrapper__Wrapper-sc-16usrgb-0 bxwPwV">
#                <svg class="Svg-sc-1bi12j5-0 EQkJl" height="24" role="img" viewbox="0 0 24 24" width="24">
#                 <path d="M4.5 13.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm15 0a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm-7.5 0a1.5 1.5 0 100-3 1.5 1.5 0 000 3z">
#                 </path>
#                </svg>
#               </span>
#              </button>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="v5CJBGtxWHZuVdLE1vKw">
#           <div class="FTTfxsCa1sJIu1Y7utDO">
#            <div class="vrjrGtquvKnX8rzOuAaA" data-testid="track-artist-link-card">
#             <div class="vreceNX3ABcxyddeS83B" style="width:80px;height:80px">
#              <img alt="Pink Floyd" aria-hidden="true" class="mMx2LUixlnN_Fu45JpFB iJp40IxKg6emF6KYJ414 OadpZJiOaGfX6Qp4j6n5 O5_0cReFdHe81E0xFAD1" data-testid="entity-image" draggable="false" loading="lazy" src="https://i.scdn.co/image/ec1fb7127168dbaa962404031409c5a293b95ec6" srcset="https://i.scdn.co/image/ec1fb7127168dbaa962404031409c5a293b95ec6 32w, https://i.scdn.co/image/ec1fb7127168dbaa962404031409c5a293b95ec6 64w, https://i.scdn.co/image/d011c95081cd9a329e506abd7ded47535d524a07 320w, https://i.scdn.co/image/d011c95081cd9a329e506abd7ded47535d524a07 640w"/>
#             </div>
#             <div class="DX4i2V_0jaKraBkfcDnR zCVFaVQz6MUyNwqjGS4c">
#              <span class="Type__TypeElement-goli3j-0 dhAODk GQqQDXMybjyriRQKH_ID">
#               Artist
#              </span>
#              <a draggable="false" href="/artist/0k17h0D3J5VfsdmQ1iZtE9">
#               <div class="Type__TypeElement-goli3j-0 edDNNU USV2e_90ZCdBCH9Dr5Vw" dir="ltr">
#                Pink Floyd
#               </div>
#              </a>
#             </div>
#             <div class="PhpDpIcERAEMvFD0NvPk">
#             </div>
#            </div>
#           </div>
#           <div data-testid="rich-track-data">
#            <div>
#             <h2 class="Type__TypeElement-goli3j-0 cWJaoY v31oEQQthIBTrzaor91k" dir="auto">
#              Popular Tracks by Pink Floyd
#             </h2>
#             <div class="QsF_2ghagKvtOMlCKmlg">
#              <div class="VVipB_gKNhrobbBulY2N">
#               <div class="nZ6SlvHDIgZshXAoDgvI">
#                <div class="vreceNX3ABcxyddeS83B" style="width:56px;height:56px">
#                 <img alt="Wish You Were Here" aria-hidden="true" class="mMx2LUixlnN_Fu45JpFB iJp40IxKg6emF6KYJ414 CxurIfvXVb_TqGF4q8Yf g3kBhX1E4EYEC2NFhhxG" data-testid="entity-image" draggable="false" loading="lazy" src="https://i.scdn.co/image/ab67616d00004851b3ca136e83344321ebd3de01" srcset="https://i.scdn.co/image/ab67616d00004851b3ca136e83344321ebd3de01 32w, https://i.scdn.co/image/ab67616d00004851b3ca136e83344321ebd3de01 64w, https://i.scdn.co/image/ab67616d00001e02b3ca136e83344321ebd3de01 150w, https://i.scdn.co/image/ab67616d00001e02b3ca136e83344321ebd3de01 300w, https://i.scdn.co/image/ab67616d0000b273b3ca136e83344321ebd3de01 320w, https://i.scdn.co/image/ab67616d0000b273b3ca136e83344321ebd3de01 640w"/>
#                </div>
#                <div class="ul8VLEzwyq253mCBVlX0">
#                 <div class="PFgcCoJSWC3KjhZxHDYH">
#                  <button aria-label="Play" class="Button-sc-1dqy6lx-0 eIVsbB" data-testid="play-button">
#                   <span aria-hidden="true" class="IconWrapper__Wrapper-sc-16usrgb-0 bxwPwV">
#                    <svg class="Svg-sc-1bi12j5-0 EQkJl" height="16" role="img" viewbox="0 0 16 16" width="16">
#                     <path d="M3 1.713a.7.7 0 011.05-.607l10.89 6.288a.7.7 0 010 1.212L4.05 14.894A.7.7 0 013 14.288V1.713z">
#                     </path>
#                    </svg>
#                   </span>
#                  </button>
#                 </div>
#                </div>
#               </div>
#               <div>
#                <div class="F689wTMuFSKj2Oo8zf3V">
#                 <a draggable="false" href="/track/1HzDhHApjdjXPLHF6GGYhu">
#                  <div class="Type__TypeElement-goli3j-0 edDNNU SFL_8OScayNetZYtCrnW" dir="auto">
#                   Wish You Were Here
#                  </div>
#                 </a>
#                </div>
#                <div class="eFtp9aRmXAJwS_cu2mtj">
#                 <span class="Type__TypeElement-goli3j-0 loEuIb OqlDFP1v7o3_liIvD2Lr">
#                  491,143,714
#                 </span>
#                </div>
#               </div>
#              </div>
#              <div>
#               <button aria-hidden="false" aria-label="More" class="Button-sc-1dqy6lx-0 kyVmlV" tabindex="0">
#                <span aria-hidden="true" class="IconWrapper__Wrapper-sc-16usrgb-0 bxwPwV">
#                 <svg class="Svg-sc-1bi12j5-0 EQkJl" height="16" role="img" viewbox="0 0 16 16" width="16">
#                  <path d="M8 3a1.5 1.5 0 110-3 1.5 1.5 0 010 3zm0 6.5a1.5 1.5 0 110-3 1.5 1.5 0 010 3zM8 16a1.5 1.5 0 110-3 1.5 1.5 0 010 3z">
#                  </path>
#                 </svg>
#                </span>
#               </button>
#              </div>
#             </div>
#             <div class="QsF_2ghagKvtOMlCKmlg">
#              <div class="VVipB_gKNhrobbBulY2N">
#               <div class="nZ6SlvHDIgZshXAoDgvI">
#                <div class="vreceNX3ABcxyddeS83B" style="width:56px;height:56px">
#                 <img alt="Another Brick In The Wall, Pt. 2 - 2011 Remastered Version" aria-hidden="true" class="mMx2LUixlnN_Fu45JpFB iJp40IxKg6emF6KYJ414 CxurIfvXVb_TqGF4q8Yf g3kBhX1E4EYEC2NFhhxG" data-testid="entity-image" draggable="false" loading="lazy" src="https://i.scdn.co/image/ab67616d00004851f34e8811de255b34c56301d8" srcset="https://i.scdn.co/image/ab67616d00004851f34e8811de255b34c56301d8 32w, https://i.scdn.co/image/ab67616d00004851f34e8811de255b34c56301d8 64w, https://i.scdn.co/image/ab67616d00001e02f34e8811de255b34c56301d8 150w, https://i.scdn.co/image/ab67616d00001e02f34e8811de255b34c56301d8 300w, https://i.scdn.co/image/ab67616d0000b273f34e8811de255b34c56301d8 320w, https://i.scdn.co/image/ab67616d0000b273f34e8811de255b34c56301d8 640w"/>
#                </div>
#                <div class="ul8VLEzwyq253mCBVlX0">
#                 <div class="PFgcCoJSWC3KjhZxHDYH">
#                  <button aria-label="Play" class="Button-sc-1dqy6lx-0 eIVsbB" data-testid="play-button">
#                   <span aria-hidden="true" class="IconWrapper__Wrapper-sc-16usrgb-0 bxwPwV">
# ...
#                 2:49
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/4mMGZQFEikumG9jhC8ZxV1">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   On The Run - 2011 Remastered Version
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 3:45
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/0OOc4CWq6Cg8fTFE1vCvwS">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Time - 2011 Remastered Version
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 6:53
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/7iyr2AP7JbsactrEySUyNX">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   The Great Gig In The Sky - 2011 Remastered Version
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 4:43
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/3aoDEt6zSuYQ47gzarlaVo">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Money - 2011 Remastered Version
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 6:22
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/5a8pT7EetH5fSv7VGEz8tN">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Us And Them - 2011 Remastered Version
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 7:49
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/6ScQOiH29VEOvkDP3UprWv">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Any Colour You Like - 2011 Remastered Version
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 3:26
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/2gCf9PqIvpKbxwfJMBWwbn">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Brain Damage - 2011 Remastered Version
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 3:46
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/7Dla2S1irAtL9VjSUIapDO">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Eclipse - 2011 Remastered Version
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 2:10
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/6EML21A4p2iDetHNhDszWU">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Speak To Me (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 2:45
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/4OCgELvC4FsHcK5sozvReH">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Breathe (In The Air) [Live At The Empire Pool, Wembley, London 1974] (2011 - Remaster)
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 2:50
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/7ebt1wJba3j5P60Q9i64oJ">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   On The Run (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 5:08
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/53gWY0fpfcGAh3gCgv5OGf">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Time (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 6:31
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/53kvKyajfIAyStjrYPbq7c">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   The Great Gig In The Sky (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 6:50
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/6w1sNUc48NCcBtyT3bnhau">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Money (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 8:40
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/0bkoUWujVTxcHm7IrhSiHa">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Us And Them (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 8:09
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/6cFHSqB77hxeTKnLAcgGqe">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Any Colour You Like (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 8:10
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/1mlUbYs5sBwcLWmzJkKHsJ">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Brain Damage (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 3:43
#                </span>
#               </div>
#              </a>
#              <a class="C08NFwm4eeeYploW7BoQ" draggable="false" href="/track/6u5sB4iGdJX97ldAgukpx7">
#               <div class="h1pJzziAIYwO154bbEtG">
#                <div class="oFwNGhN9OJGa58m3YeiN">
#                 <div class="IUiu3OTca8_mFmhdvWuu">
#                  <div class="Type__TypeElement-goli3j-0 gAmaez ilG1KBl5YrTvRzekL6gB" dir="auto">
#                   Eclipse (Live At The Empire Pool, Wembley, London 1974) [2011 - Remaster]
#                  </div>
#                 </div>
#                 <div class="Type__TypeElement-goli3j-0 ebHsEf KTLC51kEESUNYgIAqtZb" dir="auto">
#                  Pink Floyd
#                 </div>
#                </div>
#                <span class="Type__TypeElement-goli3j-0 ebHsEf xnjLjPiqkb2fW3Z_s6Ut">
#                 2:16
#                </span>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="ycxWuLy_0rZSsa4nWWLj">
#            <div class="nd0OFsnwqR1uRY5PQh_y">
#             <div class="rTMkDBDp47Eo12ZEQv4U">
#              <p class="Type__TypeElement-goli3j-0 loEuIb" dir="auto">
#               © 2011 Pink FLoyd Music Ltd/Pink Floyd (1987) Ltd under exclusive licence to Parlophone Records Ltd, a Warner Music Group Company
#              </p>
#              <p class="Type__TypeElement-goli3j-0 loEuIb" dir="auto">
#               ℗ 2011 Pink Floyd Music Ltd under exclusive licence to Parlophone Records Ltd, a Warner Music Group Company
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="wTbziZwVZMTeSzFFz4Cg">
#       </div>
#      </div>
#     </div>
#    </div>
#    <aside class="App__ModalLayer-sc-hckv0t-1 gxaSIL">
#    </aside>
#   </div>
#   <script id="initial-state" type="application/json">
#    ...
#   </script>
#   <script id="remote-configuration" type="text/plain">
#    ...
#   </script>
#   <script src="https://open.spotifycdn.com/cdn/build/mwp/vendor~mwp.03eae2cd.js">
#   </script>
#   <script src="https://open.spotifycdn.com/cdn/build/mwp/mwp.7bffc06c.js">
#   </script>
#  </body>
# </html>
